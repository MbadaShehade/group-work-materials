# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install v-diffusion-pytorch
# Out:
# Collecting v-diffusion-pytorch
#   Downloading v_diffusion_pytorch-0.0.2-py3-none-any.whl (20 kB)
# Collecting ftfy (from v-diffusion-pytorch)
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from v-diffusion-pytorch) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from v-diffusion-pytorch) (2.31.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from v-diffusion-pytorch) (9.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from v-diffusion-pytorch) (2.3.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from v-diffusion-pytorch) (0.18.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from v-diffusion-pytorch) (4.66.4)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->v-diffusion-pytorch) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->v-diffusion-pytorch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->v-diffusion-pytorch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->v-diffusion-pytorch) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->v-diffusion-pytorch) (2024.7.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->v-diffusion-pytorch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->v-diffusion-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->v-diffusion-pytorch) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->v-diffusion-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->v-diffusion-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->v-diffusion-pytorch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->v-diffusion-pytorch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->v-diffusion-pytorch) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->v-diffusion-pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->v-diffusion-pytorch) (1.25.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->v-diffusion-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->v-diffusion-pytorch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ftfy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, v-diffusion-pytorch
# Successfully installed ftfy-6.2.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 v-diffusion-pytorch-0.0.2

# %%
# !pip install nltk

import nltk
from nltk.chat.util import Chat, reflections
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
cloud_explanation = """Private Cloud: A private cloud is a cloud computing environment that is dedicated solely to one organization.
It is usually managed either by the organization itself or by a third-party service provider. The infrastructure and services are not shared
with other organizations, offering greater control, security, and customization options. Private clouds are typically used by large enterprises
or organizations with specific compliance or security requirements.
Public Cloud: A public cloud is a cloud computing environment that is hosted and managed by a third-party service provider and made available
to multiple organizations or individuals over the internet. The infrastructure and resources are shared among multiple users,
 offering scalability, flexibility, and cost-effectiveness. Public clouds are accessible to anyone who wants to use them and are often used
 for general-purpose computing needs such as web hosting, development, and testing.
Hybrid Cloud: A hybrid cloud is a computing environment that combines elements of both private and public clouds. It allows organizations
 to leverage the benefits of both environments by integrating on-premises infrastructure with public cloud resources. This integration enables
 data and applications to be dynamically moved between the two environments based on changing workload demands, security requirements, and cost
 considerations. Hybrid clouds offer greater flexibility, scalability, and customization options compared to using either private or public clouds alone.
 They are commonly used by organizations that want to retain control over sensitive data while taking advantage of the scalability and cost-effectiveness of
 public cloud services."""

# %%
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')


# Example glossary terms and their explanations
glossary_terms = {
    "CAD": "Computer-Aided Design (CAD) is the use of computer systems to assist in the creation, modification, analysis, or optimization of a design.",
    "Sketch": "A sketch in OnShape is a 2D drawing that forms the basis for creating 3D models.",
    "Extrude": "Extrude is a feature that adds depth to a 2D sketch, creating a 3D object.",
    "Assembly": "An assembly in OnShape is a collection of parts and subassemblies that are combined to create a final product.",
    "Part": "A part in OnShape is a single 3D object created from one or more sketches.",
    "Feature": "A feature in OnShape is a tool or function used to create or modify parts, such as extrude, revolve, or fillet."
}

patterns = [
    (r'hi|hello|hey', ['Hello!', 'Hi there!', 'Hey!']),
    (r'how are you?', ['I\'m good, thank you!', 'I\'m doing well, thanks for asking.']),
    (r'what is your name?', ['You can call me ChatGPT.', 'I go by the name ChatGPT.']),
    (r'my name is (.*)', ['Nice to meet you, %1.']),
    (r'thank you (.*)', ['You\'re welcome!', 'Happy to help!']),
    (r'what is the purpose of the system?', ['I can show you interesting statistics about your employees.']),
    (r'what is cloud|cloud', [cloud_explanation]),
    (r'what is onshape|onshape|on shape', ['Onshape is a cloud-based CAD platform for product design and development. Learn more here: https://www.onshape.com/']),
    (r'what is CAD', [glossary_terms['CAD']]),
    (r'what is Sketch', [glossary_terms['Sketch']]),
    (r'what is Extrude', [glossary_terms['Extrude']]),
    (r'what is Assembly', [glossary_terms['Assembly']]),
    (r'what is Part', [glossary_terms['Part']]),
    (r'what is Feature', [glossary_terms['Feature']]),
    (r'can you explain CAD', [glossary_terms['CAD']]),
    (r'can you explain Sketch', [glossary_terms['Sketch']]),
    (r'can you explain Extrude', [glossary_terms['Extrude']]),
    (r'can you explain Assembly', [glossary_terms['Assembly']]),
    (r'can you explain Part', [glossary_terms['Part']]),
    (r'can you explain Feature', [glossary_terms['Feature']]),
    # Add more patterns and responses based on your glossary index
]

# Create a chatbot
chatbot = Chat(patterns, reflections)

# Start the conversation
print("Hello! I'm ChatGPT. How can I help you today?")
while True:
    user_input = input("You: ")

    response = chatbot.respond(user_input)
    print("ChatGPT:", response)
    if user_input.lower() == 'exit' or user_input.lower() == 'bye':
        break
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Hello! I'm ChatGPT. How can I help you today?
